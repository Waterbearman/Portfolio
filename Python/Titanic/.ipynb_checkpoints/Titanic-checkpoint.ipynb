# %%
# 모듈 임포트
import pandas as pd
import numpy as np
import random as rnd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
#데이터 로드
# 절대 주소 : C:\Users\KB\Python\Kaggle\Titanic\data\train.csv
# 상대 주소 : ./data/train.csv
train_df = pd.read_csv("./data/train.csv")
train_df.shape
# Out:
# (891, 12)

# %%
test_df=pd.read_csv("./data/test.csv")
test_df.shape
# Out:
# (418, 11)

# %%
combine=[train_df, test_df]

# %%
# 데이터 설명적 분석
# train_df.head() 5개 나옴
# Pclass - 객실 등급
# SibSp - 형제 자매 배우자
# Parch - 부모, 자식
# Fare - 지불 금액
# Cabin - 객실
# Embarked - 탑승 항구
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 결측치 확인, 빈 값, null NaN na
train_df.info()
print("-"*40)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ...

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_df.describe()
# 타이타닉 실제 승객수 2224명 train 값 891명  40%
# 실제 생존율 32%, 이 데이터는 38%
# 75% 는 부모나 자녀와 여행(x)
# 25% 형제 자매 배우와 여행
#
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_df.describe(include=["object"])
# 이름은 모두 고유
# 남자가 577명 - 64%
# 탑승 항구는 3군데
#
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
train_df["Name"].sample(50)
# Out:
# 474                          Strandberg, Miss. Ida Sofia
# 756                         Carlsson, Mr. August Sigfrid
# 639                           Thorneycroft, Mr. Percival
# 121                           Moore, Mr. Leonard Charles
# 277                          Parkes, Mr. Francis "Frank"
# 293                                  Haas, Miss. Aloisia
# 725                                  Oreskovic, Mr. Luka
# 830              Yasbeck, Mrs. Antoni (Selini Alexander)
# 468                                   Scanlan, Mr. James
# 772                                    Mack, Mrs. (Mary)
# 712                             Taylor, Mr. Elmer Zebley
# 843                           Lemberopolous, Mr. Peter L
# 165      Goldsmith, Master. Frank John William "Frankie"
# 335                                   Denkoff, Mr. Mitto
# 185                                Rood, Mr. Hugh Roscoe
# 215                              Newell, Miss. Madeleine
# ...

# %%
#기술적 통계 분석 결론
# 티켓은 상관 관계 없다고 보인다 삭제 가능성
# 캐빈 결측치가 너무 많아서 삭제 가능성 이 있다.
# 패신저아이디도 삭제 가능성 ( 인덱스 부분 )
# 이름도 별로 상관관계가 보이진 않는다.
# Parch와 SibSp 기반으로 가족 구성원 총 수를 얻을 수 있다.
# 이름은 엔지니어링 해볼 필요가 있다.
# 나이는 범주형으로
# 요금 범주형

# %%
# 피벗과 그룹바이를 이용해서 분석
# 유전생존 무전탈락 
train_df[["Pclass", "Survived"]].groupby(["Pclass"],as_index=False).mean()
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
train_df[["Sex", "Survived"]].groupby(["Sex"],as_index=False).mean()
# as_index=True를 하면 sex 가 인덱스 값이여서 보기 안좋게 나온다
# sum() 으로 하면 합계가 나옴 mean() 은 확률 female - 0.742038 74퍼 입니다
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
train_df[["SibSp", "Survived"]].groupby(["SibSp"],as_index=False).mean().sort_values(by="Survived", ascending=False)
#sort_values(by="") by는 어떤걸로 정렬할지 적어 준다
#ascending 오름차순
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
train_df[["Parch", "Survived"]].groupby(["Parch"],as_index=False).mean().sort_values(by="Survived", ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
# 데이터 시각화하여 분석
# FacetGrid 여러개의 그리드 g.map 으로 그래프 출력
# bins - 데이터의 크기
g=sns.FacetGrid(train_df, col="Survived")
g.map(plt.hist, "Age", bins=20)

# %%
# 4세 이하 유아 생존율이 높았다.
# 최고령 80세분 생존 survived=1 은 생존
# 15-25세 살아 남지 못했다.
# 연령대를 범주형으로 만들면 상관관계

# %%
# aspect - 그래프 크기
grid = sns.FacetGrid(train_df, col="Survived", row="Pclass", height=2.2, aspect=1.6)
grid.map(plt.hist,"Age", alpha=.5, bins=20)

# %%
# 모델 교육을 위해 Pclass 고려 해볼 수 있다.

# %%
# 탑승지에 따른 상관 관계 분석
grid = sns.FacetGrid(train_df, row="Embarked")
grid.map(sns.pointplot, "Pclass", "Survived", "Sex")
grid.add_legend()
#grid.add_legend() 자동 범례
# Out:
# C:\Users\KB\anaconda3\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\KB\anaconda3\lib\site-packages\seaborn\axisgrid.py:675: UserWarning: Using the pointplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
grid = sns.FacetGrid(train_df, row="Embarked", col="Survived")
grid.map(sns.barplot, "Sex", "Fare", ci=None)
grid.add_legend()
# Out:
# C:\Users\KB\anaconda3\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# 요금과 상관관계가 있다 요금 범주형으로 변환

# %%
# 데이터 비틀기 ( 전처리 )
# 티켓과 캐빈은 삭제 
print("Before", train_df.shape, test_df.shape, combine[0].shape, combine[1].shape)

train_df = train_df.drop(["Ticket", "Cabin"], axis=1) # axis 행과 열 1이 들어가면 열이 삭제 
test_df = test_df.drop(["Ticket", "Cabin"], axis=1)
combine=[train_df, test_df]

print("After", train_df.shape, test_df.shape, combine[0].shape, combine[1].shape)
# Out:
# Before (891, 12) (418, 11) (891, 12) (418, 11)
# After (891, 10) (418, 9) (891, 10) (418, 9)

# %%
train_df["Name"].sample(50)
# Out:
# 205                   Strom, Miss. Telma Matilda
# 342                   Collander, Mr. Erik Gustaf
# 804                      Hedman, Mr. Oskar Arvid
# 472      West, Mrs. Edwy Arthur (Ada Mary Worth)
# 496               Eustis, Miss. Elizabeth Mussey
# 30                      Uruchurtu, Don. Manuel E
# 408            Birkeland, Mr. Hans Martin Monsen
# 735                         Williams, Mr. Leslie
# 497              Shellard, Mr. Frederick William
# 135                           Richard, Mr. Emile
# 778                      Kilgannon, Mr. Thomas J
# 853                    Lines, Miss. Mary Conover
# 589                          Murdlin, Mr. Joseph
# 6                        McCarthy, Mr. Timothy J
# 532                         Elias, Mr. Joseph Jr
# 681                           Hassab, Mr. Hammad
# 818             Holm, Mr. John Fredrik Alexander
# 213                  Givard, Mr. Hans Kristensen
# 864                       Gill, Mr. John William
# ...

# %%
extract?
# Out:
# Object `extract` not found.

# %%
# Name 에서는 닉네임만 뽑아서 쓸 수 있을 거같다. 
for dataset in combine :
    dataset["Title"]=dataset.Name.str.extract("([A-Za-z]+)\.", expand=False)

# %%
pd.crosstab(train_df["Title"], train_df["Sex"])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in combine :
    dataset["Title"] = dataset["Title"].replace(["Lady", "Countess","Capt", \
    "Don", "Dr", "Major", "Rev", "Sir", "Jonkheer", "Dona", "Col"], "Rare")
    dataset["Title"]=dataset["Title"].replace("Mlle", "Miss")
    dataset["Title"]=dataset["Title"].replace("Ms", "Miss")
    dataset["Title"]=dataset["Title"].replace("Mme", "Mrs")
    
train_df[["Title", "Survived"]].groupby(["Title"], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4    Rare  0.347826

# %%
title_mapping={"Mr":1, "Miss":2, "Mrs":3, "Master":4, "Rare":5}
for dataset in combine :
    dataset["Title"]=dataset["Title"].map(title_mapping)
    dataset["Title"]=dataset["Title"].fillna(0)
# 
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked  Title
# 0      0   7.2500        S      1
# 1      0  71.2833        C      3
# 2      0   7.9250        S      2
# 3      0  53.1000        S      3
# 4      0   8.0500        S      1

# %%
# 이름과 아이디 칼럼은 삭제
train_df = train_df.drop(["Name", "PassengerId"], axis=1)
test_df = test_df.drop(["Name", "PassengerId"], axis=1)
combine=[train_df, test_df]
# 한번 더 실행하면 오류가 나오게 된다. drop 하번 하니깐 없어져서

# %%
train_df.shape, test_df.shape
# Out:
# ((891, 9), (418, 8))

# %%
# 성별도 숫자로
for dataset in combine :
    dataset["Sex"]=dataset["Sex"].map({"female":1, "male":0}).astype(int)
train_df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0  22.0      1      0   7.2500        S      1
# 1         1       1    1  38.0      1      0  71.2833        C      3
# 2         1       3    1  26.0      0      0   7.9250        S      2
# 3         1       1    1  35.0      1      0  53.1000        S      3
# 4         0       3    0  35.0      0      0   8.0500        S      1

# %%
# 실수 한 부분 이있으면 다시 실행을 시켜야 됩니다.
# Kernel -> Restart & Run All
train_df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Title
# 0           0       3    0  22.0      1      0   7.2500        S      1
# 1           1       1    1  38.0      1      0  71.2833        C      3
# 2           1       3    1  26.0      0      0   7.9250        S      2
# 3           1       1    1  35.0      1      0  53.1000        S      3
# 4           0       3    0  35.0      0      0   8.0500        S      1
# ..        ...     ...  ...   ...    ...    ...      ...      ...    ...
# 886         0       2    0  27.0      0      0  13.0000        S      5
# 887         1       1    1  19.0      0      0  30.0000        S      2
# 888         0       3    1   NaN      1      2  23.4500        S      2
# 889         1       1    0  26.0      0      0  30.0000        C      1
# 890         0       3    0  32.0      0      0   7.7500        Q      1
#
# [891 rows x 9 columns]
